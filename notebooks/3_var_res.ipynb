# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms.v2 as transforms 
from torch.utils.data import random_split
import random 

from modules import data_loader
from modules.networks import VarResNet
from modules.networks import Net

# %% [markdown]
# ## Question 14
# see data_loader.py for how to load the data as three tensors

# %%
root = "../data/mnist-varres/train"
buckets = data_loader.load_sorted_data(root)

# %%
#split into training and validation 
train_buckets = []
val_buckets = []
torch.manual_seed(42)

for inputs, labels in buckets:

    n_total = len(inputs)
    n_val = int(n_total * 0.2)
    n_train = n_total - n_val
    

    indices = torch.randperm(n_total)
    # Slice using indices
    train_x = inputs[indices[:n_train]]
    train_y = labels[indices[:n_train]]
    
    val_x = inputs[indices[n_train:]]
    val_y = labels[indices[n_train:]]
    
    train_buckets.append((train_x, train_y))
    val_buckets.append((val_x, val_y))

# %% [markdown]
# Training loop with inner loop over the three dimensions

# %%
model = VarResNet()
optimizer = optim.Adam(model.parameters(), lr=0.001)
criterion = nn.CrossEntropyLoss()

epochs = 2
batch_size = 16

# Calculate how many full batches fit in the smallest bucket
min_samples = min(len(x) for x, y in train_buckets)
n_batches = min_samples // batch_size 

print(f"Training on {n_batches} batches per resolution..")

for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    
    # Generate shuffled indices for all buckets
    bucket_shuffles = [torch.randperm(len(x)) for x, y in train_buckets]
    
    for i in range(n_batches):
        
        # Calculate slice range for this step
        start = i * batch_size
        end = start + batch_size
        
        # loop over the three resolutions (32->48->64)
        for res_idx, (inputs_full, labels_full) in enumerate(train_buckets):
            
            batch_indices = bucket_shuffles[res_idx][start:end]
            inputs = inputs_full[batch_indices]
            labels = labels_full[batch_indices]
            
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()

    # Average loss: total loss / (batches * 3 resolutions)
    avg_loss = running_loss / (n_batches * 3)
    print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}")

print("Finished Training")
# Out:
# Training on 995 batches per resolution...
# Epoch 1, Loss: 0.2627
# Epoch 2, Loss: 0.0825
# Finished Training

# %% [markdown]
# ## Question 15
# find the value of N for which both networks have roughly the same number of parameters

# %%
def count_params(model):
    total_params = 0

    for param in model.parameters():
        num_elements = param.numel()
        total_params += num_elements
        
    return total_params

# target_params = (slope * n) + intercept
# Rearrange:
# n = (target_params - intercept) / slope

target_params = count_params(Net())
params_at_1 = count_params(VarResNet(n_channels=1))
params_at_2 = count_params(VarResNet(n_channels=2))
slope = params_at_2 - params_at_1
intercept = params_at_1 - slope

n = (target_params - intercept) / slope
print(n)

# So, rounded:
optimal_n=round(n)

# check
print(f"Fixed Model: {count_params(Net())} params")
print(f"VarRes Model: {count_params(VarResNet())} params")
# Out:
# 81.123745819398
# Fixed Model: 29066 params
# VarRes Model: 29029 params

# %% [markdown]
# ## Question 16
# Compare the validation performance of global max pooling to that of global mean pooling. Report your findings, and choose a global pooling variant.

# %%
def run_training(pooling_type, epochs=3, lr=0.001):
    print(f"\nTraining with Global {pooling_type.upper()} Pooling")
    
    model = VarResNet(n_channels=81, pooling=pooling_type)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    
    batch_size = 16
    
    # Calculate batch count based on the smallest resolution bucket
    min_samples = min(len(b[0]) for b in train_buckets)
    n_batches = min_samples // batch_size 

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        
        # Shuffle indices for each bucket at the start of every epoch
        bucket_shuffles = [torch.randperm(len(b[0])) for b in train_buckets]
        
        for i in range(n_batches):
            start = i * batch_size
            end = start + batch_size
            
            for bucket_idx, (inputs_full, labels_full) in enumerate(train_buckets):
                indices = bucket_shuffles[bucket_idx][start:end]
                inputs = inputs_full[indices]
                labels = labels_full[indices]
                
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                
                running_loss += loss.item()
        
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in val_buckets:
                outputs = model(inputs)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        # Calculate stats
        val_acc = 100 * correct / total
        avg_loss = running_loss / (n_batches * 3)
        
        print(f"Epoch {epoch+1}: Train Loss {avg_loss:.4f}, Val Acc {val_acc:.2f}%")
        
    return val_acc

# %%
acc_max = run_training('max')
acc_mean = run_training('mean')
# Out:
# Training with Global MAX Pooling
# Epoch 1: Train Loss 0.2846, Val Acc 97.16%
# Epoch 2: Train Loss 0.0810, Val Acc 98.20%
# Epoch 3: Train Loss 0.0580, Val Acc 97.67%
#
# Training with Global MEAN Pooling
# Epoch 1: Train Loss 0.8135, Val Acc 92.92%
# Epoch 2: Train Loss 0.2767, Val Acc 94.65%
# Epoch 3: Train Loss 0.1996, Val Acc 94.16%

# %% [markdown]
# ## Question 17
# comparing fixed resolution network with variable resolution

# %%
### Fixed model 

root = "../data/mnist-varres"
transform_fixed = transforms.Compose([
    transforms.Grayscale(num_output_channels=1),
    transforms.Resize((28,28)),
    transforms.ToTensor()
])

full_train_fixed = torchvision.datasets.ImageFolder(root=root + "/train", transform=transform_fixed)

# Split train/val
train_size = int(0.8 * len(full_train_fixed))
val_size = len(full_train_fixed) - train_size
train_set_fixed, val_set_fixed = random_split(full_train_fixed, [train_size, val_size], generator=torch.Generator().manual_seed(42))

# Loaders
batch_size = 16
train_loader_fixed = torch.utils.data.DataLoader(train_set_fixed, batch_size=batch_size, shuffle=True, num_workers=2)
val_loader_fixed   = torch.utils.data.DataLoader(val_set_fixed,   batch_size=batch_size, shuffle=False, num_workers=2)

# Load test set (for final comparison)
test_set_fixed = torchvision.datasets.ImageFolder(root=root + "/test", transform=transform_fixed)
test_loader_fixed = torch.utils.data.DataLoader(test_set_fixed, batch_size=batch_size, shuffle=False, num_workers=2)

model_fixed = Net()
# Out:
# /Users/rhode/Documents/GitHub/implementing_cnn/.venv/lib/python3.14/site-packages/torchvision/transforms/v2/_deprecated.py:42: UserWarning: The transform `ToTensor()` is deprecated and will be removed in a future release. Instead, please use `v2.Compose([v2.ToImage(), v2.ToDtype(torch.float32, scale=True)])`.Output is equivalent up to float precision.
#   warnings.warn(

# %%
## var model

all_buckets = data_loader.load_sorted_data(data_root=root + "/train")

train_buckets = []
val_buckets = []
torch.manual_seed(42)

for inputs, labels in all_buckets:
    n_total = len(inputs)
    n_val = int(n_total * 0.2)
    n_train = n_total - n_val
    
    indices = torch.randperm(n_total)
    
    train_buckets.append((inputs[indices[:n_train]], labels[indices[:n_train]]))
    val_buckets.append((inputs[indices[n_train:]], labels[indices[n_train:]]))

# Load test buckets (for final comparison)
test_buckets_var = data_loader.load_sorted_data(data_root=root + "/test")

model_var = VarResNet(n_channels=81, pooling='max')

# %%
def train_fixed_res(model, train_loader, val_loader, epochs=3, lr=0.001):
    print(f"\nTraining FixedResNet")
    
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr) 

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        total_epoch_loss = 0.0
        
        for i, (inputs, labels) in enumerate(train_loader):
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            total_epoch_loss += loss.item() 

            # print statistics
            if i % 200 == 199:    
                print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 200:.3f}')
                running_loss = 0.0
            
        # Validation
        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in val_loader:
                outputs = model(inputs)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
        
        val_acc = 100 * correct / total

        avg_loss = total_epoch_loss / len(train_loader)
        print(f"Epoch {epoch + 1}: Train Loss {avg_loss:.4f}, Val Acc {val_acc:.2f}%")

# %%
def train_var_res(model, train_data, val_data, epochs=3, lr=0.001, batch_size=16):
    print(f"\nTraining VarResNet")

    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    
    # Find smallest bucket size to prevent index errors
    min_samples = min(len(b[0]) for b in train_data)
    n_batches = min_samples // batch_size
    num_resolutions = len(train_data) # will be 3 (32x32, 48x48, 64x64)
    
    # for printing
    log_interval = 100

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0      # For printing (resets)
        total_epoch_loss = 0.0  # For final epoch average (never resets)
        
        # Shuffle indices
        bucket_shuffles = [torch.randperm(len(b[0])) for b in train_data]
        
        for i in range(n_batches):
            start = i * batch_size
            end = start + batch_size
            
            # loop through resolutions 
            for bucket_idx, (inputs_full, labels_full) in enumerate(train_data):
                
                indices = bucket_shuffles[bucket_idx][start:end]
                inputs = inputs_full[indices]
                labels = labels_full[indices]
                
                optimizer.zero_grad()
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                
                running_loss += loss.item()
                total_epoch_loss += loss.item()

            # for print statements
            if (i + 1) % log_interval == 0:
                # Average over: log_interval * number of resolutions
                avg_running = running_loss / (log_interval * num_resolutions)
                print(f'[{epoch + 1}, {i + 1:5d} bucket-sets] loss: {avg_running:.3f}')
                running_loss = 0.0

        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for inputs, labels in val_data:
                outputs = model(inputs)
                _, predicted = torch.max(outputs, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        val_acc = 100 * correct / total
        
        total_updates = n_batches * num_resolutions
        avg_loss = total_epoch_loss / total_updates
        
        print(f"Epoch {epoch+1}: Train Loss {avg_loss:.4f}, Val Acc {val_acc:.2f}%")

# %%
train_fixed_res(model_fixed, train_loader_fixed, val_loader_fixed, epochs=5, lr=0.0003)
train_var_res(model_var, train_buckets, val_buckets, epochs=5, lr=0.0003, batch_size=16)
# Out:
# Training FixedResNet
# [1,   200] loss: 0.145
# [1,   400] loss: 0.142
# [1,   600] loss: 0.136
# [1,   800] loss: 0.141
# [1,  1000] loss: 0.142
# [1,  1200] loss: 0.123
# [1,  1400] loss: 0.145
# [1,  1600] loss: 0.149
# [1,  1800] loss: 0.127
# [1,  2000] loss: 0.138
# [1,  2200] loss: 0.141
# [1,  2400] loss: 0.156
# [1,  2600] loss: 0.139
# [1,  2800] loss: 0.135
# [1,  3000] loss: 0.161
# Epoch 1: Train Loss 0.1413, Val Acc 95.28%
# [2,   200] loss: 0.112
# [2,   400] loss: 0.127
# [2,   600] loss: 0.138
# [2,   800] loss: 0.119
# [2,  1000] loss: 0.116
# [2,  1200] loss: 0.130
# [2,  1400] loss: 0.142
# [2,  1600] loss: 0.109
# [2,  1800] loss: 0.114
# [2,  2000] loss: 0.150
# [2,  2200] loss: 0.135
# [2,  2400] loss: 0.121
# [2,  2600] loss: 0.121
# [2,  2800] loss: 0.145
# [2,  3000] loss: 0.111
# Epoch 2: Train Loss 0.1261, Val Acc 95.41%
# [3,   200] loss: 0.101
# [3,   400] loss: 0.112
# [3,   600] loss: 0.106
# [3,   800] loss: 0.104
# [3,  1000] loss: 0.119
# [3,  1200] loss: 0.118
# [3,  1400] loss: 0.099
# [3,  1600] loss: 0.127
# [3,  1800] loss: 0.129
# [3,  2000] loss: 0.101
# [3,  2200] loss: 0.126
# [3,  2400] loss: 0.113
# [3,  2600] loss: 0.113
# [3,  2800] loss: 0.102
# [3,  3000] loss: 0.117
# Epoch 3: Train Loss 0.1125, Val Acc 95.00%
# [4,   200] loss: 0.114
# [4,   400] loss: 0.093
# [4,   600] loss: 0.118
# [4,   800] loss: 0.089
# [4,  1000] loss: 0.081
# [4,  1200] loss: 0.111
# [4,  1400] loss: 0.111
# [4,  1600] loss: 0.105
# [4,  1800] loss: 0.124
# [4,  2000] loss: 0.097
# [4,  2200] loss: 0.093
# [4,  2400] loss: 0.088
# [4,  2600] loss: 0.103
# [4,  2800] loss: 0.124
# [4,  3000] loss: 0.096
# Epoch 4: Train Loss 0.1031, Val Acc 95.72%
# [5,   200] loss: 0.093
# [5,   400] loss: 0.090
# [5,   600] loss: 0.077
# [5,   800] loss: 0.104
# [5,  1000] loss: 0.079
# [5,  1200] loss: 0.091
# [5,  1400] loss: 0.085
# [5,  1600] loss: 0.103
# [5,  1800] loss: 0.101
# [5,  2000] loss: 0.093
# [5,  2200] loss: 0.095
# [5,  2400] loss: 0.080
# [5,  2600] loss: 0.088
# [5,  2800] loss: 0.089
# [5,  3000] loss: 0.118
# Epoch 5: Train Loss 0.0923, Val Acc 95.56%
#
# Training VarResNet
# [1,    20 bucket-sets] loss: 0.014
# [1,    40 bucket-sets] loss: 0.006
# [1,    60 bucket-sets] loss: 0.017
# [1,    80 bucket-sets] loss: 0.025
# [1,   100 bucket-sets] loss: 0.016
# [1,   120 bucket-sets] loss: 0.011
# [1,   140 bucket-sets] loss: 0.010
# [1,   160 bucket-sets] loss: 0.028
# [1,   180 bucket-sets] loss: 0.021
# [1,   200 bucket-sets] loss: 0.031
# [1,   220 bucket-sets] loss: 0.032
# [1,   240 bucket-sets] loss: 0.009
# [1,   260 bucket-sets] loss: 0.014
# [1,   280 bucket-sets] loss: 0.008
# [1,   300 bucket-sets] loss: 0.014
# [1,   320 bucket-sets] loss: 0.015
# [1,   340 bucket-sets] loss: 0.019
# [1,   360 bucket-sets] loss: 0.018
# [1,   380 bucket-sets] loss: 0.019
# [1,   400 bucket-sets] loss: 0.035
# [1,   420 bucket-sets] loss: 0.027
# [1,   440 bucket-sets] loss: 0.011
# [1,   460 bucket-sets] loss: 0.022
# [1,   480 bucket-sets] loss: 0.024
# [1,   500 bucket-sets] loss: 0.014
# [1,   520 bucket-sets] loss: 0.031
# [1,   540 bucket-sets] loss: 0.021
# [1,   560 bucket-sets] loss: 0.016
# [1,   580 bucket-sets] loss: 0.014
# [1,   600 bucket-sets] loss: 0.024
# [1,   620 bucket-sets] loss: 0.012
# [1,   640 bucket-sets] loss: 0.016
# [1,   660 bucket-sets] loss: 0.016
# [1,   680 bucket-sets] loss: 0.016
# [1,   700 bucket-sets] loss: 0.029
# [1,   720 bucket-sets] loss: 0.016
# [1,   740 bucket-sets] loss: 0.034
# [1,   760 bucket-sets] loss: 0.024
# [1,   780 bucket-sets] loss: 0.030
# [1,   800 bucket-sets] loss: 0.029
# [1,   820 bucket-sets] loss: 0.017
# [1,   840 bucket-sets] loss: 0.024
# [1,   860 bucket-sets] loss: 0.027
# [1,   880 bucket-sets] loss: 0.014
# [1,   900 bucket-sets] loss: 0.016
# [1,   920 bucket-sets] loss: 0.014
# [1,   940 bucket-sets] loss: 0.022
# [1,   960 bucket-sets] loss: 0.017
# [1,   980 bucket-sets] loss: 0.016
# Epoch 1: Train Loss 0.0193, Val Acc 98.52%
# [2,    20 bucket-sets] loss: 0.007
# [2,    40 bucket-sets] loss: 0.018
# [2,    60 bucket-sets] loss: 0.010
# [2,    80 bucket-sets] loss: 0.021
# [2,   100 bucket-sets] loss: 0.012
# [2,   120 bucket-sets] loss: 0.005
# [2,   140 bucket-sets] loss: 0.013
# [2,   160 bucket-sets] loss: 0.017
# [2,   180 bucket-sets] loss: 0.007
# [2,   200 bucket-sets] loss: 0.024
# [2,   220 bucket-sets] loss: 0.015
# [2,   240 bucket-sets] loss: 0.010
# [2,   260 bucket-sets] loss: 0.023
# [2,   280 bucket-sets] loss: 0.021
# [2,   300 bucket-sets] loss: 0.008
# [2,   320 bucket-sets] loss: 0.013
# [2,   340 bucket-sets] loss: 0.032
# [2,   360 bucket-sets] loss: 0.025
# [2,   380 bucket-sets] loss: 0.023
# [2,   400 bucket-sets] loss: 0.016
# [2,   420 bucket-sets] loss: 0.012
# [2,   440 bucket-sets] loss: 0.029
# [2,   460 bucket-sets] loss: 0.016
# [2,   480 bucket-sets] loss: 0.010
# [2,   500 bucket-sets] loss: 0.008
# [2,   520 bucket-sets] loss: 0.010
# [2,   540 bucket-sets] loss: 0.020
# [2,   560 bucket-sets] loss: 0.016
# [2,   580 bucket-sets] loss: 0.023
# [2,   600 bucket-sets] loss: 0.022
# [2,   620 bucket-sets] loss: 0.017
# [2,   640 bucket-sets] loss: 0.015
# [2,   660 bucket-sets] loss: 0.014
# [2,   680 bucket-sets] loss: 0.009
# [2,   700 bucket-sets] loss: 0.018
# [2,   720 bucket-sets] loss: 0.010
# [2,   740 bucket-sets] loss: 0.008
# [2,   760 bucket-sets] loss: 0.008
# [2,   780 bucket-sets] loss: 0.009
# [2,   800 bucket-sets] loss: 0.016
# [2,   820 bucket-sets] loss: 0.021
# [2,   840 bucket-sets] loss: 0.014
# [2,   860 bucket-sets] loss: 0.015
# [2,   880 bucket-sets] loss: 0.020
# [2,   900 bucket-sets] loss: 0.027
# [2,   920 bucket-sets] loss: 0.008
# [2,   940 bucket-sets] loss: 0.007
# [2,   960 bucket-sets] loss: 0.016
# [2,   980 bucket-sets] loss: 0.020
# Epoch 2: Train Loss 0.0155, Val Acc 98.52%
# [3,    20 bucket-sets] loss: 0.008
# [3,    40 bucket-sets] loss: 0.005
# [3,    60 bucket-sets] loss: 0.010
# [3,    80 bucket-sets] loss: 0.013
# [3,   100 bucket-sets] loss: 0.016
# [3,   120 bucket-sets] loss: 0.004
# [3,   140 bucket-sets] loss: 0.011
# [3,   160 bucket-sets] loss: 0.014
# [3,   180 bucket-sets] loss: 0.007
# [3,   200 bucket-sets] loss: 0.012
# [3,   220 bucket-sets] loss: 0.035
# [3,   240 bucket-sets] loss: 0.013
# [3,   260 bucket-sets] loss: 0.009
# [3,   280 bucket-sets] loss: 0.011
# [3,   300 bucket-sets] loss: 0.006
# [3,   320 bucket-sets] loss: 0.018
# [3,   340 bucket-sets] loss: 0.020
# [3,   360 bucket-sets] loss: 0.008
# [3,   380 bucket-sets] loss: 0.010
# [3,   400 bucket-sets] loss: 0.020
# [3,   420 bucket-sets] loss: 0.011
# [3,   440 bucket-sets] loss: 0.006
# [3,   460 bucket-sets] loss: 0.013
# [3,   480 bucket-sets] loss: 0.011
# [3,   500 bucket-sets] loss: 0.014
# [3,   520 bucket-sets] loss: 0.017
# [3,   540 bucket-sets] loss: 0.020
# [3,   560 bucket-sets] loss: 0.013
# [3,   580 bucket-sets] loss: 0.015
# [3,   600 bucket-sets] loss: 0.008
# [3,   620 bucket-sets] loss: 0.004
# [3,   640 bucket-sets] loss: 0.023
# [3,   660 bucket-sets] loss: 0.013
# [3,   680 bucket-sets] loss: 0.009
# [3,   700 bucket-sets] loss: 0.021
# [3,   720 bucket-sets] loss: 0.010
# [3,   740 bucket-sets] loss: 0.017
# [3,   760 bucket-sets] loss: 0.032
# [3,   780 bucket-sets] loss: 0.020
# [3,   800 bucket-sets] loss: 0.023
# [3,   820 bucket-sets] loss: 0.010
# [3,   840 bucket-sets] loss: 0.015
# [3,   860 bucket-sets] loss: 0.013
# [3,   880 bucket-sets] loss: 0.010
# [3,   900 bucket-sets] loss: 0.021
# [3,   920 bucket-sets] loss: 0.010
# [3,   940 bucket-sets] loss: 0.018
# [3,   960 bucket-sets] loss: 0.016
# [3,   980 bucket-sets] loss: 0.017
# Epoch 3: Train Loss 0.0139, Val Acc 98.61%
# [4,    20 bucket-sets] loss: 0.013
# [4,    40 bucket-sets] loss: 0.015
# [4,    60 bucket-sets] loss: 0.013
# [4,    80 bucket-sets] loss: 0.008
# [4,   100 bucket-sets] loss: 0.007
# [4,   120 bucket-sets] loss: 0.010
# [4,   140 bucket-sets] loss: 0.008
# [4,   160 bucket-sets] loss: 0.009
# [4,   180 bucket-sets] loss: 0.014
# [4,   200 bucket-sets] loss: 0.012
# [4,   220 bucket-sets] loss: 0.014
# [4,   240 bucket-sets] loss: 0.011
# [4,   260 bucket-sets] loss: 0.004
# [4,   280 bucket-sets] loss: 0.006
# [4,   300 bucket-sets] loss: 0.007
# [4,   320 bucket-sets] loss: 0.005
# [4,   340 bucket-sets] loss: 0.009
# [4,   360 bucket-sets] loss: 0.007
# [4,   380 bucket-sets] loss: 0.016
# [4,   400 bucket-sets] loss: 0.004
# [4,   420 bucket-sets] loss: 0.008
# [4,   440 bucket-sets] loss: 0.030
# [4,   460 bucket-sets] loss: 0.010
# [4,   480 bucket-sets] loss: 0.012
# [4,   500 bucket-sets] loss: 0.020
# [4,   520 bucket-sets] loss: 0.015
# [4,   540 bucket-sets] loss: 0.007
# [4,   560 bucket-sets] loss: 0.020
# [4,   580 bucket-sets] loss: 0.009
# [4,   600 bucket-sets] loss: 0.011
# [4,   620 bucket-sets] loss: 0.013
# [4,   640 bucket-sets] loss: 0.008
# [4,   660 bucket-sets] loss: 0.011
# [4,   680 bucket-sets] loss: 0.024
# [4,   700 bucket-sets] loss: 0.019
# [4,   720 bucket-sets] loss: 0.024
# [4,   740 bucket-sets] loss: 0.010
# [4,   760 bucket-sets] loss: 0.011
# [4,   780 bucket-sets] loss: 0.010
# [4,   800 bucket-sets] loss: 0.010
# [4,   820 bucket-sets] loss: 0.011
# [4,   840 bucket-sets] loss: 0.016
# [4,   860 bucket-sets] loss: 0.009
# [4,   880 bucket-sets] loss: 0.017
# [4,   900 bucket-sets] loss: 0.021
# [4,   920 bucket-sets] loss: 0.014
# [4,   940 bucket-sets] loss: 0.010
# [4,   960 bucket-sets] loss: 0.018
# [4,   980 bucket-sets] loss: 0.021
# Epoch 4: Train Loss 0.0124, Val Acc 98.55%
# [5,    20 bucket-sets] loss: 0.004
# [5,    40 bucket-sets] loss: 0.006
# [5,    60 bucket-sets] loss: 0.007
# [5,    80 bucket-sets] loss: 0.013
# [5,   100 bucket-sets] loss: 0.002
# [5,   120 bucket-sets] loss: 0.004
# [5,   140 bucket-sets] loss: 0.006
# [5,   160 bucket-sets] loss: 0.009
# [5,   180 bucket-sets] loss: 0.012
# [5,   200 bucket-sets] loss: 0.009
# [5,   220 bucket-sets] loss: 0.007
# [5,   240 bucket-sets] loss: 0.010
# [5,   260 bucket-sets] loss: 0.020
# [5,   280 bucket-sets] loss: 0.010
# [5,   300 bucket-sets] loss: 0.017
# [5,   320 bucket-sets] loss: 0.014
# [5,   340 bucket-sets] loss: 0.011
# [5,   360 bucket-sets] loss: 0.025
# [5,   380 bucket-sets] loss: 0.009
# [5,   400 bucket-sets] loss: 0.006
# [5,   420 bucket-sets] loss: 0.006
# [5,   440 bucket-sets] loss: 0.008
# [5,   460 bucket-sets] loss: 0.012
# [5,   480 bucket-sets] loss: 0.014
# [5,   500 bucket-sets] loss: 0.007
# [5,   520 bucket-sets] loss: 0.013
# [5,   540 bucket-sets] loss: 0.008
# [5,   560 bucket-sets] loss: 0.009
# [5,   580 bucket-sets] loss: 0.007
# [5,   600 bucket-sets] loss: 0.013
# [5,   620 bucket-sets] loss: 0.009
# [5,   640 bucket-sets] loss: 0.004
# [5,   660 bucket-sets] loss: 0.014
# [5,   680 bucket-sets] loss: 0.013
# [5,   700 bucket-sets] loss: 0.013
# [5,   720 bucket-sets] loss: 0.016
# [5,   740 bucket-sets] loss: 0.005
# [5,   760 bucket-sets] loss: 0.011
# [5,   780 bucket-sets] loss: 0.015
# [5,   800 bucket-sets] loss: 0.014
# [5,   820 bucket-sets] loss: 0.011
# [5,   840 bucket-sets] loss: 0.005
# [5,   860 bucket-sets] loss: 0.024
# [5,   880 bucket-sets] loss: 0.017
# [5,   900 bucket-sets] loss: 0.017
# [5,   920 bucket-sets] loss: 0.019
# [5,   940 bucket-sets] loss: 0.012
# [5,   960 bucket-sets] loss: 0.010
# [5,   980 bucket-sets] loss: 0.005
# Epoch 5: Train Loss 0.0108, Val Acc 98.38%

# %%
# Test fixed
correct = 0
total = 0
model_fixed.eval()
with torch.no_grad():
    for inputs, labels in test_loader_fixed:
        outputs = model_fixed(inputs)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print(f"Fixed Resolution Test Accuracy: {100 * correct / total:.2f}%")

# Test var
correct = 0
total = 0
model_var.eval()
with torch.no_grad():
    for inputs, labels in test_buckets_var:
        outputs = model_var(inputs)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
print(f"Variable Resolution Test Accuracy: {100 * correct / total:.2f}%")
# Out:
# Fixed Resolution Test Accuracy: 96.03%
# Variable Resolution Test Accuracy: 98.53%
